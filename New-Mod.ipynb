# %%
from ultralytics import YOLO
from pathlib import Path

model = YOLO("yolo11s.pt")
results = model.train(
    data=str(Path(r".\data.yaml")),
    epochs=50,
    imgsz=640,
    batch=8,
    device=0,
    workers=0,
    cache=False,
    project=str(Path(r".\runs")),
    name="screw_detection_v2"
)
# Out:
# ...
# New https://pypi.org/project/ultralytics/8.4.36 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.31  Python-3.13.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 3050 6GB Laptop GPU, 6144MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO("C:/kaggle/runs/screw_detection_v2/weights/best.pt")

results = model("C:/Users/orion/Downloads/6251278024514934513.jpg")

results[0].show()
# Out:
# image 1/1 C:\Users\orion\Downloads\6251278024514934513.jpg: 608x640 13 screws, 122.3ms
# Speed: 5.4ms preprocess, 122.3ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
